# %%
# %config IPCompleter.greedy=True

# %%
from mongoengine import Document, fields
from database.connection import Mongo
mongo = Mongo()
mongo.connect()

# %%
class Test(Document):
    file = fields.FileField()

# %%
bin_img = open("test_image.png", "rb")

# %%
bin_img
# Out:
# <_io.BufferedReader name='test_image.png'>

# %%
test = Test()
test.file.put(bin_img)
test.save()
# Out:
# <Test: Test object>

# %%
y = Test()
y.file.put(bin_img)
y.save()
# Out:
# <Test: Test object>

# %%
Test.objects.count()
# Out:
# 20

# %%
from PIL import Image
from io import BytesIO

# %%
im = Image.open(bin_img)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=180x281 at 0x7FC755296EE0>

# %%
im.format
# Out:
# 'JPEG'

# %%
from datetime import datetime
class compare(Document):

    time = fields.DateTimeField(default=datetime.utcnow)
    first = fields.FileField()
    second = fields.FileField()

# %%
y = compare()
y.first.put(bin_img)
y.second.put(bin_img)
y.save()
# Out:
# <compare: compare object>

# %%
compare.objects.first()
# Out:
# <compare: compare object>
